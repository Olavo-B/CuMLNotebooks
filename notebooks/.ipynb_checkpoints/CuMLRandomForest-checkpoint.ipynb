# %%
import pandas as pd
import numpy as np

# %%
import warnings

warnings.filterwarnings("ignore", category=UserWarning, module="cuml")
warnings.filterwarnings("ignore", category=UserWarning, module="conda")

# %% [markdown]
# ## Importando Dataset
#
# Basta escolher o metodo referente ao dataset e tirar o comentário

# %%
from LoadDataset import LoadDataset


data,target = LoadDataset.load_covtype()


data = data.astype(np.float32)

# %% [markdown]
# ## Rodar Random Forest

# %%
def run_random_forest_mg(new_data, target, _n_estimators, _max_depth, debug=False):
    import numpy as np
    import sklearn
    from sklearn import model_selection
    
    import pandas as pd
    import cudf
    import cuml
    import time
    import gc
    
    from cuml import datasets
    from cuml.model_selection import train_test_split
    from cuml.metrics import accuracy_score
    from cuml.dask.common import utils as dask_utils
    from dask.distributed import Client, wait
    from dask_cuda import LocalCUDACluster
    import dask_cudf
    import dask
    
    from cuml.dask.ensemble import RandomForestClassifier as cumlDaskRF

    # Check if there is already a Dask client running
    if not dask.config.get("distributed.client"):
        # This will use all GPUs on the local host by default
        cluster = LocalCUDACluster(threads_per_worker=1)
        c = Client(cluster)
        
        # Query the client for all connected workers
        workers = c.has_what().keys()
        n_workers = len(workers)
        n_streams = 8  # Performance optimization
        
        if debug: print(f"Created a new cluster with {n_workers} workers and {n_streams} streams.")
    else:
        c = Client()  # Use the existing client if available
        workers = c.has_what().keys()
        n_workers = len(workers)
        n_streams = 8  # Performance optimization
        
        if debug: print(f"Using existing cluster with {n_workers} workers and {n_streams} streams.")

    if debug:
        print(f'N workers: {n_workers}')

    if n_workers > _n_estimators:
        _n_estimators = n_workers

    # Converter os dados para um DataFrame do cudf
    X_cudf = new_data
    y_cudf = cudf.Series(target)

    X_cudf = X_cudf.astype(np.float32)
    y_cudf = y_cudf.astype(np.int32)

    
    # Dividir os dados em conjuntos de treinamento e teste
    X_train, X_test, y_train, y_test = model_selection.train_test_split(X_cudf, y_cudf, test_size=0.2, random_state=42)

    n_partitions = n_workers

    def distribute(X, y):
        # First convert to cudf (with real data, you would likely load in cuDF format to start)
        X_cudf = cudf.DataFrame(X)
        y_cudf = cudf.Series(y)
    
        # Partition with Dask
        # In this case, each worker will train on 1/n_partitions fraction of the data
        X_dask = dask_cudf.from_cudf(X_cudf, npartitions=n_partitions)
        y_dask = dask_cudf.from_cudf(y_cudf, npartitions=n_partitions)
    
        # Persist to cache the data in active memory
        X_dask, y_dask = \
          dask_utils.persist_across_workers(c, [X_dask, y_dask], workers=workers)
        
        return X_dask, y_dask
    
    X_train_dask, y_train_dask = distribute(X_train, y_train)
    X_test_dask, y_test_dask = distribute(X_test, y_test)

    rf = cumlDaskRF(max_depth=_max_depth, n_estimators=_n_estimators,
                    n_streams=n_streams)

    start_time = time.time()
    rf.fit(X_train_dask, y_train_dask)
    end_time = time.time()

    wait(rf.rfs) # Allow asynchronous training tasks to finish
    
    if debug:
        print(f'Tempo de treinamento do modelo RandomForest {_n_estimators},{_max_depth}: {end_time - start_time} segundos')
    
    # Fazer previsões no conjunto de teste
    y_pred = rf.predict(X_test_dask).compute().to_numpy()
    
    # del X_train, X_test, y_train, X_cudf, y_cudf
    # gc.collect()
    
    # Calcular a acurácia
    accuracy = accuracy_score(y_test, y_pred)
    if debug:
        print(f'Acurácia do modelo RandomForest {_n_estimators},{_max_depth}: {accuracy}')

    # # Limpar a memória da GPU
    # del y_test, y_pred
    # gc.collect()
    
    return accuracy, rf

# %%
def run_random_forest(new_data, target, _n_estimators, _max_depth, debug=False):
      from cuml.ensemble import RandomForestClassifier
      from cuml.metrics import accuracy_score
      from cuml.model_selection import train_test_split
      import cudf
      import time
      import gc


      # Converter os dados para um DataFrame do cudf
      X_cudf = new_data
      y_cudf = cudf.Series(target)

      # Dividir os dados em conjuntos de treinamento e teste
      X_train, X_test, y_train, y_test = train_test_split(X_cudf, y_cudf, test_size=0.2, random_state=42)


      # Instanciar e treinar o modelo RandomForest
      rf = RandomForestClassifier(n_estimators=_n_estimators,
                                  max_depth = _max_depth,
                                  random_state=42)

      start_time = time.time()
      rf.fit(X_train, y_train)
      end_time = time.time()

      if debug:
        print(f'Tempo de treinamento do modelo RandomForest {_n_estimators},{_max_depth}: {end_time - start_time} segundos')

      # Fazer previsões no conjunto de teste
      y_pred = rf.predict(X_test)

      # del X_train, X_test, y_train, X_cudf, y_cudf
      # gc.collect()

      # Calcular a acurácia
      accuracy = accuracy_score(y_test, y_pred)
      if debug:
        print(f'Acurácia do modelo RandomForest {_n_estimators},{_max_depth}: {accuracy}')

      # # Limpar a memória da GPU
      # del y_test, y_pred
      # gc.collect()

      return accuracy, rf

# %%
import cudf
import numpy as np
from tqdm import tqdm

# Convert the data to a cuDF DataFrame
data = cudf.DataFrame(data)

# Defining the values for N-trees and depth
n_trees = np.arange(8, 105, 5)  # From 5 to 100, multiples of 5
depth = np.arange(8, 105, 5)    # From 5 to 100, multiples of 5

accs = []

# Outer loop for n_trees with tqdm for progress bar
with tqdm(total=len(n_trees) * len(depth), desc="Processing RF") as pbar:
    for n in n_trees:
        for d in depth:
            acc, rf = run_random_forest(data, target, n, d, debug=False)
            accs.append((n, d, acc))
            # Update the progress bar and display the current iteration details
            pbar.set_postfix({'N-trees': n, 'Depth': d, 'Accuracy': f"{acc:.4f}"})
            pbar.update(1)
# Out:
# /opt/conda/lib/python3.12/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.                                                                                                             | 0/400 [00:00<?, ?it/s]
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 45589 instead
#   warnings.warn(
# /opt/conda/lib/python3.12/site-packages/distributed/client.py:3371: UserWarning: Sending large graph of size 104.73 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /opt/conda/lib/python3.12/site-packages/distributed/client.py:3371: UserWarning: Sending large graph of size 26.26 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /opt/conda/lib/python3.12/site-packages/cuml/internals/api_decorators.py:344: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return func(**kwargs)
# /opt/conda/lib/python3.12/site-packages/cuml/internals/api_decorators.py:344: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return func(**kwargs)
# /opt/conda/lib/python3.12/site-packages/cuml/internals/api_decorators.py:344: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return func(**kwargs)
# /opt/conda/lib/python3.12/site-packages/cuml/internals/api_decorators.py:344: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return func(**kwargs)
# /opt/conda/lib/python3.12/site-packages/cuml/internals/api_decorators.py:344: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return func(**kwargs)
# /opt/conda/lib/python3.12/site-packages/cuml/internals/api_decorators.py:344: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return func(**kwargs)
# /opt/conda/lib/python3.12/site-packages/cuml/internals/api_decorators.py:344: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return func(**kwargs)
# /opt/conda/lib/python3.12/site-packages/cuml/internals/api_decorators.py:344: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return func(**kwargs)
# /opt/conda/lib/python3.12/site-packages/cuml/internals/api_decorators.py:344: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return func(**kwargs)
# /opt/conda/lib/python3.12/site-packages/cuml/internals/api_decorators.py:344: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return func(**kwargs)
# /opt/conda/lib/python3.12/site-packages/cuml/internals/api_decorators.py:344: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return func(**kwargs)
# /opt/conda/lib/python3.12/site-packages/cuml/internals/api_decorators.py:344: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return func(**kwargs)
# /opt/conda/lib/python3.12/site-packages/cuml/internals/api_decorators.py:344: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return func(**kwargs)
# /opt/conda/lib/python3.12/site-packages/cuml/internals/api_decorators.py:344: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return func(**kwargs)
# /opt/conda/lib/python3.12/site-packages/cuml/internals/api_decorators.py:344: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return func(**kwargs)
# /opt/conda/lib/python3.12/site-packages/cuml/internals/api_decorators.py:344: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return func(**kwargs)
# Processing RF:   0%|                                                                                                                                                                                                   | 0/400 [00:25<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 18
#      16 for n in n_trees:
#      17     for d in depth:
# ---> 18         acc, rf = run_random_forest_mg(data, target, n, d, debug=False)
#      19         accs.append((n, d, acc))
#      20         # Update the progress bar and display the current iteration details
#
# Cell In[15], line 94, in run_random_forest_mg(new_data, target, _n_estimators, _max_depth, debug)
#      91     print(f'Tempo de treinamento do modelo RandomForest {_n_estimators},{_max_depth}: {end_time - start_time} segundos')
#      93 # Fazer previsões no conjunto de teste
# ---> 94 y_pred = rf.predict(X_test_dask).compute().to_numpy()
#      96 # del X_train, X_test, y_train, X_cudf, y_cudf
#      97 # gc.collect()
#      98
#      99 # Calcular a acurácia
#     100 accuracy = accuracy_score(y_test, y_pred)
#
# File /opt/conda/lib/python3.12/site-packages/cuml/dask/ensemble/randomforestclassifier.py:382, in RandomForestClassifier.predict(self, X, algo, threshold, convert_dtype, predict_model, fil_sparse_format, delayed, broadcast_data)
#     374         preds = self.partial_inference(
#     375             X,
#     376             algo=algo,
#    (...)
#     379             delayed=delayed,
#     380         )
#     381     else:
# --> 382         preds = self._predict_using_fil(
#     383             X,
#     384             algo=algo,
#     385             threshold=threshold,
#     386             convert_dtype=convert_dtype,
#     387             fil_sparse_format=fil_sparse_format,
#     388             delayed=delayed,
#     389         )
#     390 return preds
#
# File /opt/conda/lib/python3.12/site-packages/cuml/dask/ensemble/base.py:224, in BaseRandomForestModel._predict_using_fil(self, X, delayed, **kwargs)
#     222 def _predict_using_fil(self, X, delayed, **kwargs):
#     223     if self._get_internal_model() is None:
# --> 224         self._set_internal_model(self._concat_treelite_models())
#     225     data = DistributedDataHandler.create(X, client=self.client)
#     226     if self._get_internal_model() is None:
#
# File /opt/conda/lib/python3.12/site-packages/cuml/dask/ensemble/base.py:190, in BaseRandomForestModel._concat_treelite_models(self)
#     184 model = self.rfs[last_worker].result()
#     185 all_tl_mod_handles = [
#     186     model._tl_handle_from_bytes(indiv_worker_model_bytes)
#     187     for indiv_worker_model_bytes in mod_bytes
#     188 ]
# --> 190 model._concatenate_treelite_handle(all_tl_mod_handles)
#     191 for tl_handle in all_tl_mod_handles:
#     192     TreeliteModel.free_treelite_model(tl_handle)
#
# File randomforest_common.pyx:347, in cuml.ensemble.randomforest_common.BaseRandomForestModel._concatenate_treelite_handle()
#
# RuntimeError: [23:26:22] /home/conda/feedstock_root/build_artifacts/treelite_1721254173150/work/src/model_concat.cc:53: Check failed: concatenated_model->num_class == objs[i]->num_class: Model object at index 1has a different num_class than the first model object (at index 0)
# 2025-01-14 23:34:44,673 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/site-packages/distributed/worker.py", line 1269, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/utils_comm.py", line 441, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/utils_comm.py", line 420, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/core.py", line 1259, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/opt/conda/lib/python3.12/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:42488 remote=tcp://127.0.0.1:35711>: Stream is closed
# 2025-01-14 23:34:44,674 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/site-packages/distributed/worker.py", line 1269, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/utils_comm.py", line 441, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/utils_comm.py", line 420, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/core.py", line 1259, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/opt/conda/lib/python3.12/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:42476 remote=tcp://127.0.0.1:35711>: Stream is closed
# 2025-01-14 23:34:44,677 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/site-packages/distributed/worker.py", line 1269, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/utils_comm.py", line 441, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/utils_comm.py", line 420, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/core.py", line 1259, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/opt/conda/lib/python3.12/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:42472 remote=tcp://127.0.0.1:35711>: Stream is closed
# 2025-01-14 23:34:44,677 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/site-packages/distributed/worker.py", line 1269, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/utils_comm.py", line 441, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/utils_comm.py", line 420, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/core.py", line 1259, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/opt/conda/lib/python3.12/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:42502 remote=tcp://127.0.0.1:35711>: Stream is closed
# 2025-01-14 23:34:44,680 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/site-packages/distributed/worker.py", line 1269, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/utils_comm.py", line 441, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/utils_comm.py", line 420, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/core.py", line 1259, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/opt/conda/lib/python3.12/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:42530 remote=tcp://127.0.0.1:35711>: Stream is closed
# 2025-01-14 23:34:44,683 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/site-packages/distributed/worker.py", line 1269, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/utils_comm.py", line 441, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/utils_comm.py", line 420, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/core.py", line 1259, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/opt/conda/lib/python3.12/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:42518 remote=tcp://127.0.0.1:35711>: Stream is closed
# 2025-01-14 23:34:44,721 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:32791' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('frompandas-07f0c20ed4a36474d848a8e3955d6e00', 2), ('frompandas-a0da05b06c9c0e38ffa73d51f7bb3e9e', 2), '_construct_rf-64c6a613-8df8-4d05-9625-1923d0d54ca1', ('frompandas-f29a67fa601ee9e319e459f76aa52a1f', 2), ('frompandas-b908166601b4f88a7ea6433a7100312b', 2)} (stimulus_id='handle-worker-cleanup-1736897684.7210426')
# 2025-01-14 23:34:44,724 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:38403' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('frompandas-b908166601b4f88a7ea6433a7100312b', 1), ('frompandas-07f0c20ed4a36474d848a8e3955d6e00', 1), ('frompandas-a0da05b06c9c0e38ffa73d51f7bb3e9e', 1), ('frompandas-f29a67fa601ee9e319e459f76aa52a1f', 1), '_construct_rf-66b40df6-6171-4a85-ba0f-5555aa1ce374'} (stimulus_id='handle-worker-cleanup-1736897684.7245715')
# 2025-01-14 23:34:44,726 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:34427' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'_construct_rf-2347f296-70da-4f54-816d-af98df6f9087', ('frompandas-b908166601b4f88a7ea6433a7100312b', 7), ('frompandas-07f0c20ed4a36474d848a8e3955d6e00', 7), ('frompandas-a0da05b06c9c0e38ffa73d51f7bb3e9e', 7), ('frompandas-f29a67fa601ee9e319e459f76aa52a1f', 7)} (stimulus_id='handle-worker-cleanup-1736897684.726848')
# 2025-01-14 23:34:45,075 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35969' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('frompandas-f29a67fa601ee9e319e459f76aa52a1f', 9), ('frompandas-b908166601b4f88a7ea6433a7100312b', 9), '_construct_rf-ee491bf0-2f07-473e-9d34-c50657506bc9', ('frompandas-07f0c20ed4a36474d848a8e3955d6e00', 9), ('frompandas-a0da05b06c9c0e38ffa73d51f7bb3e9e', 9)} (stimulus_id='handle-worker-cleanup-1736897685.0756533')
# 2025-01-14 23:34:45,077 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:43105' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('frompandas-b908166601b4f88a7ea6433a7100312b', 4), ('frompandas-07f0c20ed4a36474d848a8e3955d6e00', 4), ('frompandas-a0da05b06c9c0e38ffa73d51f7bb3e9e', 4), ('frompandas-f29a67fa601ee9e319e459f76aa52a1f', 4), '_construct_rf-10188882-1b66-490c-8a1e-959d388c973e'} (stimulus_id='handle-worker-cleanup-1736897685.0777779')
# 2025-01-14 23:34:45,079 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39079' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('frompandas-07f0c20ed4a36474d848a8e3955d6e00', 8), ('frompandas-a0da05b06c9c0e38ffa73d51f7bb3e9e', 8), ('frompandas-f29a67fa601ee9e319e459f76aa52a1f', 8), '_construct_rf-c729d895-e1cc-4f69-9dfc-4beda6fa50d9', ('frompandas-b908166601b4f88a7ea6433a7100312b', 8)} (stimulus_id='handle-worker-cleanup-1736897685.0790722')
# 2025-01-14 23:34:45,097 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44891' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('frompandas-07f0c20ed4a36474d848a8e3955d6e00', 11), ('frompandas-a0da05b06c9c0e38ffa73d51f7bb3e9e', 11), ('frompandas-f29a67fa601ee9e319e459f76aa52a1f', 11), '_construct_rf-b2a45705-9f5e-41f5-82b7-78d9a90a124c', ('frompandas-b908166601b4f88a7ea6433a7100312b', 11)} (stimulus_id='handle-worker-cleanup-1736897685.0967479')
# 2025-01-14 23:34:45,099 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39349' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('frompandas-a0da05b06c9c0e38ffa73d51f7bb3e9e', 5), ('frompandas-07f0c20ed4a36474d848a8e3955d6e00', 5), ('frompandas-f29a67fa601ee9e319e459f76aa52a1f', 5), ('frompandas-b908166601b4f88a7ea6433a7100312b', 5), '_construct_rf-4a944e20-4673-40e1-82e4-1e6545138cc5'} (stimulus_id='handle-worker-cleanup-1736897685.099345')
# 2025-01-14 23:34:45,158 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39027' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('frompandas-b908166601b4f88a7ea6433a7100312b', 3), ('frompandas-f29a67fa601ee9e319e459f76aa52a1f', 3), ('frompandas-07f0c20ed4a36474d848a8e3955d6e00', 3), ('frompandas-a0da05b06c9c0e38ffa73d51f7bb3e9e', 3), '_construct_rf-3cb30543-8b43-4c72-8b79-f4e335fa8b9a'} (stimulus_id='handle-worker-cleanup-1736897685.1578078')
# 2025-01-14 23:34:45,177 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:46171' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('frompandas-f29a67fa601ee9e319e459f76aa52a1f', 12), '_construct_rf-f576ea36-5aff-4a45-8887-8981ab36ac19', ('frompandas-b908166601b4f88a7ea6433a7100312b', 12), ('frompandas-a0da05b06c9c0e38ffa73d51f7bb3e9e', 12), ('frompandas-07f0c20ed4a36474d848a8e3955d6e00', 12)} (stimulus_id='handle-worker-cleanup-1736897685.1768968')
# 2025-01-14 23:34:45,186 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:38589' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('frompandas-b908166601b4f88a7ea6433a7100312b', 14), ('frompandas-07f0c20ed4a36474d848a8e3955d6e00', 14), ('frompandas-a0da05b06c9c0e38ffa73d51f7bb3e9e', 14), ('frompandas-f29a67fa601ee9e319e459f76aa52a1f', 14), '_construct_rf-4b86e5ff-532a-44f5-8a1c-02bccaaeb4a0'} (stimulus_id='handle-worker-cleanup-1736897685.1854734')
# 2025-01-14 23:34:45,189 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33597' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'_construct_rf-a5e098a5-2b52-4a25-8ab3-ac74b47568e1', ('frompandas-b908166601b4f88a7ea6433a7100312b', 0), ('frompandas-07f0c20ed4a36474d848a8e3955d6e00', 0), ('frompandas-a0da05b06c9c0e38ffa73d51f7bb3e9e', 0), ('frompandas-f29a67fa601ee9e319e459f76aa52a1f', 0)} (stimulus_id='handle-worker-cleanup-1736897685.189166')
# 2025-01-14 23:34:45,190 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:46763' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('frompandas-f29a67fa601ee9e319e459f76aa52a1f', 15), ('frompandas-b908166601b4f88a7ea6433a7100312b', 15), '_construct_rf-c2406649-1fad-4cf4-9051-eb02d81f61a5', ('frompandas-07f0c20ed4a36474d848a8e3955d6e00', 15), ('frompandas-a0da05b06c9c0e38ffa73d51f7bb3e9e', 15)} (stimulus_id='handle-worker-cleanup-1736897685.1907816')
# 2025-01-14 23:34:45,191 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42473' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('frompandas-b908166601b4f88a7ea6433a7100312b', 10), ('frompandas-07f0c20ed4a36474d848a8e3955d6e00', 10), ('frompandas-a0da05b06c9c0e38ffa73d51f7bb3e9e', 10), ('frompandas-f29a67fa601ee9e319e459f76aa52a1f', 10), '_construct_rf-1e2f4255-c981-4732-9269-a738bb793294'} (stimulus_id='handle-worker-cleanup-1736897685.191827')
# 2025-01-14 23:34:45,193 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:41195' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('frompandas-b908166601b4f88a7ea6433a7100312b', 13), ('frompandas-07f0c20ed4a36474d848a8e3955d6e00', 13), ('frompandas-a0da05b06c9c0e38ffa73d51f7bb3e9e', 13), '_construct_rf-77940198-e6ad-4c72-b6f5-745067b89020', ('frompandas-f29a67fa601ee9e319e459f76aa52a1f', 13)} (stimulus_id='handle-worker-cleanup-1736897685.1929348')
# 2025-01-14 23:34:45,193 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:36433' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('frompandas-b908166601b4f88a7ea6433a7100312b', 6), ('frompandas-07f0c20ed4a36474d848a8e3955d6e00', 6), ('frompandas-a0da05b06c9c0e38ffa73d51f7bb3e9e', 6), '_construct_rf-a3510f28-6bc2-45c2-95b6-8d12fb7ea30f', ('frompandas-f29a67fa601ee9e319e459f76aa52a1f', 6)} (stimulus_id='handle-worker-cleanup-1736897685.193781')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Convert the list to a DataFrame
graph = pd.DataFrame(accs, columns=['n_trees', 'depth', 'accuracy'])

graph = graph[
    (graph['n_trees'] >= 5) & (graph['n_trees'] <= 50) &
    (graph['depth'] >= 5) & (graph['depth'] <= 50)
]

# Pivot the DataFrame to create a matrix format suitable for a heatmap
heatmap_data = graph.pivot(index="n_trees", columns="depth", values="accuracy")

# Create the heatmap
plt.figure(figsize=(20, 18))
sns.heatmap(heatmap_data, annot=True, fmt=".4f", cmap="viridis", cbar_kws={'label': 'Accuracy'})

# Add labels and title
plt.title("Accuracy Heatmap")
plt.xlabel("Depth")
plt.ylabel("Number of Trees")

# Save the heatmap to a file
plt.savefig("accuracy_heatmap_covtype.png", dpi=300, bbox_inches='tight')

# Show the plot
plt.show()
